# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
path = os.getcwd() + '/dane1.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])

# %%
# ex.1
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
# ex.2
x = data['Population']
y = data['Profit']
plt.scatter(x,y)
plt.show()

# %%
# ex.3, ex.4
data.insert(0, "Ones", 1) 
data.head()
# Out:
#    Ones  Population   Profit
# 0     1      6.1101  17.5920
# 1     1      5.5277   9.1302
# 2     1      8.5186  13.6620
# 3     1      7.0032  11.8540
# 4     1      5.8598   6.8233

# %%
x = data[['Ones', 'Population']]
y = data[['Profit']]
x.head()
# Out:
#    Ones  Population
# 0     1      6.1101
# 1     1      5.5277
# 2     1      8.5186
# 3     1      7.0032
# 4     1      5.8598

# %%
y.head()
# Out:
#     Profit
# 0  17.5920
# 1   9.1302
# 2  13.6620
# 3  11.8540
# 4   6.8233

# %%
x = np.matrix(x.values)
y = np.matrix(y.values)
theta = np.zeros((x.shape[1], 1))

# %%
# ex.5, ex.6
def computeCost(_x, _y, _theta):
    # 2-3 code lines as series of matrix operation
    m = _x.shape[0]
    f_x = _x * _theta
    # f_x = np.dot(x, theta)
    residuals = f_x - _y
    return np.sum(np.square(residuals)) / (2 * m)

# %%
# ex.7
computeCost(x,y,theta)
# Out:
# 32.072733877455676

# %%
# ex.8
def gradient_prosty(_x, _y, _theta, _alpha, _it):
    m = len(_y)
    cost_history = np.zeros(_it)
    for i in range(0,_it):
        f_x = _x * _theta
        residuals = f_x - _y
        _theta = _theta - (1/m) * _alpha * (_x.T * residuals)
        cost_history[i] = computeCost(_x,_y, _theta)
    
    return _theta, cost_history

# %%
alpha = 0.01
it = 1000
gradient_prosty(x,y,theta,alpha, it)
# Out:
# (matrix([[-3.24140214],
#          [ 1.1272942 ]]),
#  array([6.73719046, 5.93159357, 5.90115471, 5.89522859, 5.89009494,
#         5.88500416, 5.87993248, 5.87487909, 5.86984391, 5.86482687,
#         5.85982789, 5.85484692, 5.84988389, 5.84493874, 5.8400114 ,
#         5.83510181, 5.8302099 , 5.82533562, 5.82047889, 5.81563965,
#         5.81081784, 5.8060134 , 5.80122627, 5.79645638, 5.79170367,
#         5.78696808, 5.78224955, 5.77754801, 5.77286341, 5.76819568,
#         5.76354477, 5.75891061, 5.75429313, 5.7496923 , 5.74510803,
#         5.74054027, 5.73598897, 5.73145406, 5.72693549, 5.72243319,
#         5.71794711, 5.71347718, 5.70902336, 5.70458558, 5.70016379,
#         5.69575792, 5.69136792, 5.68699373, 5.6826353 , 5.67829257,
#         5.67396548, 5.66965398, 5.665358  , 5.6610775 , 5.65681242,
#         5.6525627 , 5.64832829, 5.64410913, 5.63990517, 5.63571635,
#         5.63154261, 5.62738391, 5.6232402 , 5.6191114 , 5.61499748,
# ...

# %%
# ex.9
results = []
best_result = None
optimal_parameters = None
for alpha in np.arange(0,0.4,0.01):
    for it in range(1000,5000,1000):
        theta_result, cost_result = gradient_prosty(x,y,theta,alpha, it)
        results.append((theta_result, cost_result))
        if not best_result or cost_result[-1] < best_result:
            best_result = cost_result[-1]
            optimal_parameters = theta_result
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in square
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in subtract

# %%
for i in results:
    print(i)

print("best result", best_result)
print("optimal parameters", optimal_parameters)
# Out:
# (matrix([[0.],
#         [0.]]), array([32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
#        32.07273388, 32.07273388, 32.07273388, 32.07273388, 32.07273388,
# ...

# %%
# ex.10
theta = np.matrix(np.array([-3.24140214, 1.1272942])).T
print("Cost for theta = {} is equal {} ".format(theta, computeCost(x,y,theta)))
# Out:
# Cost for theta = [[-3.24140214]
#  [ 1.1272942 ]] is equal 4.51595550361189

# %%
# ex.11
x_old = data['Population']
x_regression = np.arange(5, 25)
theta_f = list(theta.flat)
y_predict = theta_f[0] + theta_f[1] * x_regression
plt.plot(x_regression,y_predict,'r-')
plt.plot(x_old,y,'b.')
plt.xlabel("$x$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
# Out:
# Text(0, 0.5, '$y$')

# %%
# ex.12
alpha = 0.01
it = 1000
theta_result, cost_history_result = gradient_prosty(x,y,theta,alpha,it)
fig,ax = plt.subplots(figsize=(12,8))

ax.set_ylabel('Cost')
ax.set_xlabel('Iterations')
ax.plot(range(it),cost_history_result,'b.')
